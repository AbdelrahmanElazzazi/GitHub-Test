# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # <center> **My Jupyter Notebook on IBM Watson Studio**

# %% [markdown]
# > ## **Abdelrahman El Azzazi**

# %% [markdown]
# > ## Operations Manager

# %% [markdown]
# > ### *I am interested in "Data Science" beacuse I like to do analysis on it and gain some valuable information and feedback from it.*

# %% [markdown]
# - ### **The below code is written for visualizing some simple data using two popular libraries in Python:-**

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
# Generate 100 random data points along 3 dimensions

# %%
x, y, scale = np.random.randn(3, 100)

# %%
fig, ax = plt.subplots()

# %%
# Map each onto a scatterplot we'll create with Matplotlib

# %%
ax.scatter( x=x, y=y, c=scale, s=np.abs(scale)*500)

# %%
ax.set( title = "Some Random Data, Created With JupyterLab")
# Out:
# [Text(0.5, 1.0, 'Some Random Data, Created With JupyterLab')]

# %%
plt.show()

# %% [markdown]
# -  # ***One***

# %% [markdown]
# - # ***Two***

# %% [markdown]
# - # ***Three***

# %% [markdown]
# - # ***Four***

# %% [markdown]
# 1.

# %% [markdown]
# 2.

# %% [markdown]
# 3.

# %% [markdown]
# 1.
# 2.
# 3.

# %% [markdown]
# 4.

# %% [markdown]
# 5.

# %% [markdown]
# -------------------------------

# %% [markdown]
# # <a href="https://github.com/AbdelrahmanElazzazi/GitHub-Test">www.Jupyter.lab</a>

# %% [markdown]
# | ID | Name     | Price |
# |----|:----------:|:-------:|
# | 01 | Cheese   | \$45  |
# | 02 | Milk     | \$10  |
# | 03 | Bread    | \$15  |

# %% [markdown]
# | Id | Label    | Price |
# |--- |----------| ------|
# | 01 | Markdown |\$1600 |
# | 02 | is       |  \$12 |
# | 03 | AWESOME  | \$999 |

# %% [markdown]
# ## ~~Just ignore this sentence~~
